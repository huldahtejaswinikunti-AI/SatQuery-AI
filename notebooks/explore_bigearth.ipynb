# %% [markdown]
# # SatQuery AI — Exploring BigEarthNet Multi-Modal Patches
# Inspect Sentinel-1 SAR and Sentinel-2 optical co-registered arrays.

# %%
from satquery.perception.spectral_indices import compute_spectral_indices
from satquery.perception.sar_backscatter import analyze_sar_backscatter
print('SatQuery perception tools loaded successfully.')
